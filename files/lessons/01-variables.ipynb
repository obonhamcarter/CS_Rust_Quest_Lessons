# %% [markdown]
# # Quest 1: Variables - Your Starter Toolkit 🦀
#
# Welcome! This notebook is beginner-friendly and uses Rust examples.
#
# Run code in Rust Playground: <https://play.rust-lang.org/>

# %% [markdown]
# ## Rust Example
#
# ```rust
# fn main() {
#     let mut hp = 3;
#     hp += 1;
#     println!("HP: {}", hp);
# }
# ```

# %% [markdown]
# ## Gentle Challenge
#
# 1. Copy the Rust snippet into Rust Playground.
# 2. Change one value.
# 3. Re-run and describe what changed.

# %% [markdown]
# Want full notes? Open `lessons/01-variables.qmd`.
