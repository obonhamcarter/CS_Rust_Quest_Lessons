# %% [markdown]
# # Quest 18: Wrappers - Add Behavior Around Functions 🦀
#
# Welcome! This notebook is beginner-friendly and uses Rust examples.
#
# Run code in Rust Playground: <https://play.rust-lang.org/>

# %% [markdown]
# ## Rust Example
#
# ```rust
# fn with_logging<F>(name: &str, action: F) where F: Fn() {
#     println!("[start] {}", name);
#     action();
#     println!("[end] {}", name);
# }
# fn main() { with_logging("demo", || println!("hello")); }
# ```

# %% [markdown]
# ## Gentle Challenge
#
# 1. Copy the Rust snippet into Rust Playground.
# 2. Change one value.
# 3. Re-run and describe what changed.

# %% [markdown]
# Want full notes? Open `lessons/18-decorators.qmd`.
