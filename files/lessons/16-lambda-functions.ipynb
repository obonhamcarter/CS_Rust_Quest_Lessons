# %% [markdown]
# # Quest 16: Closures - Quick Function Tools 🦀
#
# Welcome! This notebook is beginner-friendly and uses Rust examples.
#
# Run code in Rust Playground: <https://play.rust-lang.org/>

# %% [markdown]
# ## Rust Example
#
# ```rust
# fn main() {
#     let nums = vec![1, 2, 3];
#     let doubled: Vec<i32> = nums.iter().map(|n| n * 2).collect();
#     println!("{:?}", doubled);
# }
# ```

# %% [markdown]
# ## Gentle Challenge
#
# 1. Copy the Rust snippet into Rust Playground.
# 2. Change one value.
# 3. Re-run and describe what changed.

# %% [markdown]
# Want full notes? Open `lessons/16-lambda-functions.qmd`.
